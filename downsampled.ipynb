# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
 
img1 = cv2.imread('virat.jpg',0)
 
[m, n] = img1.shape
print('Image Shape:', m, n)
 
print('Original Image:')
plt.imshow(img1, cmap="gray")
 
f = 9
 
img2 = np.zeros((m//f, n//f), dtype=np.int)
 
for i in range(0, m, f):
    for j in range(0, n, f):
        try:
 
            img2[i//f][j//f] = img1[i][j]
        except IndexError:
            pass

print('Down Sampled Image:')
plt.imshow(img2, cmap="gray")
# Out:
# Image Shape: 634 950
# Original Image:
# Down Sampled Image:
# C:\Users\User\AppData\Local\Temp/ipykernel_10752/3050838202.py:15: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   img2 = np.zeros((m//f, n//f), dtype=np.int)
