# %%
import cv2
import os
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
 
#Set the path where images are stored
img_dir = "D:\same format\png" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*')
files = glob.glob(data_path)
data = []
for f1 in files:
    img = cv2.imread(f1)
    data.append(img)
    plt.figure()
    plt.imshow(img)
