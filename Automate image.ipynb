# %%
from PIL import Image
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\image processing'

# %%
image1 = Image.open("virat.jpg")

image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=950x634 at 0x27004D45490>

# %%
image1.show()
image1.save("pic1.png")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'abcd.CR2',
#  'aspect ratio.ipynb',
#  'auto.png',
#  'black bg.jpg',
#  'car2.png',
#  'cat_damaged.png',
#  'cat_mask.png',
#  'CREDIT @RYANBREITKREUTZ - P1073455.RW2',
#  'dice.jpg',
#  'dimage_inpainted.png',
#  'Displaying all images.ipynb',
#  'Displaying random images .ipynb',
#  'Downsamp.png',
#  'downsampled.ipynb',
#  'flower image.png',
#  'force.png',
#  'FreeMono.otf',
#  'FreeMonoBold.ttf',
#  'Height width channel.ipynb',
#  'image.jpg',
#  'image.png',
#  'image1.jpg',
#  'image2.jpg',
#  'images.jpg',
#  'img.png',
#  'jpg.ipynb',
#  'my.png',
#  'Nearest Interpolation.ipynb',
#  'objrem.jpg',
#  'pic1.png',
#  'pqrs.CR2',
#  'Remove part of an image.ipynb',
#  'remove text.ipynb',
#  'resizing the image.ipynb',
#  'Restoring Damaged Image.ipynb',
#  'Restoring Object.ipynb',
#  'shrinking images in one folder.ipynb',
#  'signal to noise.ipynb',
#  'text_removed_image.jpg',
#  'Untitled (3).ipynb',
#  'Untitled.ipynb',
# ...

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        print(fn, "&", fext)
# Out:
# black bg & .jpg
# dice & .jpg
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11592/1785158030.py in <module>
#       1 for f in os.listdir("."):
#       2     if f.endswith(".jpg"):
# ----> 3         i = Image.open(f)
#       4         fn, fext = os.path.splitext(f)
#       5         print(fn, "&", fext)
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3028     for message in accept_warnings:
#    3029         warnings.warn(message)
# -> 3030     raise UnidentifiedImageError(
#    3031         "cannot identify image file %r" % (filename if filename else fp)
#    3032     )
#
# UnidentifiedImageError: cannot identify image file 'image.jpg'

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        print(f)
# Out:
# black bg.jpg
# dice.jpg
# image.jpg
# image1.jpg
# image2.jpg
# images.jpg
# objrem.jpg
# text_removed_image.jpg
# virat resized.jpg
# virat.jpg
